# %%
# !pip install -q ipywidgets
# !pip install -q torch langchain langgraph pydantic typing_extensions
# !pip install -q langchain-huggingface langchain_community langchain_ollama
# !pip install -q sentence_transformers faiss-cpu

# %%
import os
import asyncio

# Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# Run Ollama in the background
os.environ['OLLAMA_HOST'] = '0.0.0.0'
# !nohup ollama serve &

# Give it a moment to start up
await asyncio.sleep(5)

# Model for the RAG application
# !ollama pull qwen3:8b

# Evaluator model
# !ollama pull qwen3:30b
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# nohup: appending output to 'nohup.out'

# %%
import json
import torch
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.schema import Document, StrOutputParser
from langchain_ollama.llms import OllamaLLM
from sentence_transformers.cross_encoder import CrossEncoder
from langgraph.graph import StateGraph, END, START
from typing_extensions import TypedDict
from typing import List, Any, Union

# --- Global Variables ---
retriever = None
reranker = None
rag_app = None

# --- Graph State Definition ---
class GraphState(TypedDict):
    question: str
    generation: str
    documents: Union[List[Document], List[dict]]
    llm: Any

# --- Node Functions (Retrieve, Filter, Generate) ---

def retrieve_node(state):
    documents = retriever.invoke(state["question"])
    print(f"---NODE: RETRIEVE (Completed)---")
    print(f"  Retrieved {len(documents)} document chunks.")
    return {"documents": documents}


def documents_filter_node(state):
    question = state["question"]
    documents = state["documents"]
    llm = state["llm"]

    system = """You are a document relevance grader for a chatbot that assists in Vietnamese traditional medicine. Your goal is to filter out document that is not relevant to the user's question.

    Instructions:
    1. A document is considered RELEVANT ('y') if it contains information that is relevant to the user's question, even if it does not cover every single detail in the question.
    2. A document is NOT RELEVANT ('n') only if it is completely off-topic.
    3. Your job is to filter out entirely irrelevant documents, not to answer the question. Do not be overly strict.

    Conclude with a single character: 'y' if relevant or 'n' if not relevant. /no_think"""

    prompt = ChatPromptTemplate.from_messages([
        ("system", system),
        ("human", "Document:\n\n{document}\n\nQuestion: {question}"),
    ])
    grader = prompt | llm | StrOutputParser()

    filtered_docs = []
    grading_results_log = []

    for d in documents:
        doc_content = d.metadata.get("source_record")
        if not doc_content:
            continue
        response_str = grader.invoke({"question": question, "document": doc_content})
        decision_part = re.sub(r"<think>.*?</think>", "", response_str, flags=re.DOTALL).strip().lower()
        final_word = decision_part.split()[-1] if decision_part.split() else ""
        grade = "no"
        if "y" in final_word:
            grade = "yes"
            filtered_docs.append(d)
        doc_name = doc_content.get('name', 'Unknown')[:40]
        grading_results_log.append(f"  - Doc: '{doc_name}...' -> Grade: {grade.upper()}")

    print("---NODE: GRADE DOCUMENTS (Completed)---")
    print("\n".join(grading_results_log))

    return {"documents": filtered_docs}


def rerank_documents_node(state):
    print("---NODE: RERANK DOCUMENTS---")
    question = state["question"]
    documents = state["documents"]

    if not documents:
        return {"documents": []}

    # Create pairs of [question, document_content] for the reranker
    pairs = []
    for d in documents:
        # Rerank based on the text content that was embedded
        pairs.append([question, d.page_content])

    # Get scores from the reranker model
    scores = reranker.predict(pairs)

    # Combine documents with their scores
    scored_docs = list(zip(scores, documents))

    # Sort documents by score in descending order
    scored_docs.sort(key=lambda x: x[0], reverse=True)

    # Filter out documents below a relevance threshold and keep the top N
    final_docs = []
    rerank_log = []
    print("  Reranking results:")
    for score, doc in scored_docs:
        doc_name = doc.metadata.get("source_record", {}).get('name', 'Unknown')[:40]
        rerank_log.append(f"  - Doc: '{doc_name}...' -> Score: {score:.4f}")
        if score > 0.3:
            final_docs.append(doc)
        # Limit to the top 5 most relevant documents
        if len(final_docs) >= 5:
            break
    print("\n".join(rerank_log))
    print(f"  Passing {len(final_docs)} documents to the generator.")
    return {"documents": final_docs}


def generate_node(state):
    question = state["question"]
    documents = state["documents"]
    llm = state["llm"]

    source_records = [
        doc.metadata.get("source_record")
        for doc in documents if hasattr(doc, 'metadata') and doc.metadata.get("source_record")
    ]

    prompt_text = """You are an assistant in Vietnamese traditional medicine. Your task is to synthesize information from all provided documents to give a comprehensive answer to the user's question.

    Instructions:
    1.  Carefully read the user's question and analyze **every document** provided in the context.
    2.  Identify all documents from the context that are relevant to the user's question. If all the documents are not relevant, tell the user that no relevant document could be found.
    3.  Construct a final answer that begins with a clear introductory sentence.
    4.  Then, present the relevant medicine in a numbered list. For each medicine, state its name and clearly explain how the properties and its used is helpful. If the medicine has side-effect please tell it to the user.
    5.  Conclude with a summary statement if appropriate.
    6.  Do not make up information. Base your entire answer ONLY on the provided context.
    7.  Your final, synthesized answer must be in **Vietnamese**.

    Context:
    {context}

    Question: {question}
    Synthesized Answer (in Vietnamese):"""

    prompt_template = PromptTemplate.from_template(prompt_text)
    rag_chain = prompt_template | llm | StrOutputParser()
    generation = rag_chain.invoke({"context": source_records, "question": question})
    print("---NODE: GENERATE (Completed)---")

    return {"generation": generation, "documents": source_records}


def load_and_prepare_rag():
    global retriever, rag_app, reranker
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"--- Using device: {device} ---")

    documents = []
    with open('./merged_data.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
    for record in data:
        page_content = (
            f"Tên vị thuốc: {record.get('name', '')}. "
            f"Chi tiết: {record.get('detail', '')}. "
            f"Tóm tắt: {record.get('summaried', '')}"
        )
        doc = Document(page_content=page_content, metadata={'source_record': record})
        documents.append(doc)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=3000, chunk_overlap=40)
    chunks = text_splitter.split_documents(documents)

    embeddings = HuggingFaceEmbeddings(
        model_name="BAAI/bge-m3",
        model_kwargs={"device": device, "trust_remote_code": True}
    )
    vectorstore = FAISS.from_documents(chunks, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 30})
    print("✅ Retriever đã sẵn sàng!")

    reranker = CrossEncoder('BAAI/bge-reranker-v2-m3', max_length=8192, device=device, trust_remote_code=True)
    print("✅ Reranker đã sẵn sàng!")

    workflow = StateGraph(GraphState)
    workflow.add_node("retrieve", retrieve_node)
    workflow.add_node("documents_filter_node", documents_filter_node)
    workflow.add_node("rerank_documents", rerank_documents_node)
    workflow.add_node("generate", generate_node)
    workflow.add_edge(START, "retrieve")
    workflow.add_edge("retrieve", "documents_filter_node")
    workflow.add_edge("documents_filter_node", "rerank_documents")
    # workflow.add_edge("retrieve", "rerank_documents")
    workflow.add_edge("rerank_documents", "generate")
    workflow.add_edge("generate", END)
    rag_app = workflow.compile()
    print("✅ Graph đã được biên dịch và sẵn sàng!")

load_and_prepare_rag()
# Out:
# --- Using device: cpu ---
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# ✅ Retriever đã sẵn sàng!
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# ✅ Reranker đã sẵn sàng!
# ✅ Graph đã được biên dịch và sẵn sàng!

# %% [markdown]
# ## Chatbot UI

# %%
import re

input_box = widgets.Textarea(placeholder='Hãy nhập câu hỏi của bạn...', layout={'width': '90%', 'height': '100px'})
submit_button = widgets.Button(description='Gửi câu hỏi', button_style='success', icon='paper-plane')
output_area = widgets.Output(layout={'border': '1px solid black', 'padding': '10px'})

def on_button_click(b):
    with output_area:
        clear_output()
        print("🤔 Đang xử lý, vui lòng chờ...")
        query = input_box.value
        if not query:
            clear_output(); print("⚠️ Vui lòng nhập câu hỏi."); return

        try:
            # llm = OllamaLLM(model="qwen3:8b", num_ctx=10000, reasoning=False)
            llm = OllamaLLM(model="qwen3:8b", num_ctx=10000)
            inputs = {"question": query, "llm": llm}
            final_state = rag_app.invoke(inputs)

            generation = final_state.get('generation', "Không thể tạo câu trả lời.")
            documents = final_state.get('documents', [])

            clear_output()

            # Parse for <think> tags and create dropdown for it
            match = re.search(r"<think>(.*?)</think>", generation, re.DOTALL)

            if match:
                thinking_process = match.group(1).strip()
                final_answer = re.sub(r"<think>.*?</think>", "", generation, flags=re.DOTALL).strip()

                think_accordion = widgets.Accordion(children=[widgets.HTML(f"<pre><code>{thinking_process}</code></pre>")])
                think_accordion.set_title(0, 'Xem quá trình suy luận 🤔')
                think_accordion.selected_index = None

                display(think_accordion)
                display(Markdown(f"### 💬 Câu trả lời của Bot:\n{final_answer}"))
            else:
                display(Markdown(f"### 💬 Câu trả lời của Bot:\n{generation}"))

            # Display sources in a collapsible dropdown ---
            if documents:
                # Create an HTML formatted string for the sources
                sources_html = "<ul>"
                for i, doc in enumerate(documents):
                    sources_html += f"<li><b>Nguồn {i+1}:</b> <code>{json.dumps(doc, indent=2, ensure_ascii=False)}</code></li>"
                sources_html += "</ul>"

                # Create the accordion for sources
                sources_accordion = widgets.Accordion(children=[widgets.HTML(sources_html)])
                sources_accordion.set_title(0, 'Xem các nguồn tài liệu đã sử dụng 📚')
                sources_accordion.selected_index = None # Start collapsed

                display(sources_accordion)

        except Exception as e:
            clear_output()
            display(Markdown(f"**Lỗi:** Gặp sự cố trong quá trình xử lý: `{e}`"))

submit_button.on_click(on_button_click)
display(widgets.VBox([input_box, submit_button, output_area]))
# Out:
# VBox(children=(Textarea(value='', layout=Layout(height='100px', width='90%'), placeholder='Hãy nhập câu hỏi củ…

# %% [markdown]
# ## Đánh giá mô hình

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.runnables import RunnableLambda
import pandas as pd
import re

# %%
judge_llm = OllamaLLM(model="qwen3:30b", num_ctx=10000, reasoning=None)

# %%
# Custom parser function to extract <think> tags and the JSON object
def parse_think_and_json(llm_output: str) -> dict:
    """
    Parses the raw LLM output to extract reasoning from <think> tags and a score from a JSON object.
    """
    try:
        # Dind content within <think> tags
        think_match = re.search(r'<think>(.*?)</think>', llm_output, re.DOTALL)
        reasoning = think_match.group(1).strip() if think_match else "No reasoning found in <think> tags."

        # Find the JSON block
        json_match = re.search(r'\{.*\}', llm_output, re.DOTALL)
        if json_match:
            json_data = json.loads(json_match.group(0))
            score = json_data.get('score')
        else:
            score = None

        return {"score": score, "reasoning": reasoning}

    except (json.JSONDecodeError, AttributeError):
        return {"score": None, "reasoning": "Error parsing LLM output."}

# %%
# --- Answer Relevance ---
answer_relevance_prompt = ChatPromptTemplate.from_template(
    """You are an expert evaluator of a RAG system. Your single task is to assess if a generated answer is relevant to a user's question.

    **--- CRITICAL INSTRUCTION 1: IGNORE FACTUALITY ---**
    You must completely IGNORE whether the information in the answer is factually correct. Your evaluation must be based *only* on whether the answer's topic and content directly address the user's question. Fact-checking is handled by a different evaluator.

    **--- CRITICAL INSTRUCTION 2: HANDLING ADDITIONAL INFORMATION ---**
    The answer may list several medicines. For each medicine, it might describe multiple uses. **If a medicine is included because at least one of its uses is relevant to the question, you should NOT penalize the answer for also listing its other, non-relevant uses.** This additional information is considered acceptable context. Only penalize the answer if it includes medicines whose properties are *entirely* unrelated to the user's question.

    **Scoring Guide (continuous scale from 0.0 to 1.0):**
    - 1.0: The answer is perfectly relevant and directly addresses all aspects of the question, following the rules above.
    - 0.75: The answer is relevant and addresses the main points of the question.
    - 0.5: The answer is partially relevant but incomplete or tangential.
    - 0.25: The answer has minor relevance but does not address the main point of the question.
    - 0.0: The answer is completely irrelevant to the question.

    **User Question:**
    {question}

    **Generated Answer:**
    {answer}

    Provide your final evaluation as a JSON object with a single key: "score".

    JSON Response:
    """
)

# --- Context Relevance ---
context_relevance_prompt = ChatPromptTemplate.from_template(
    """You are an expert evaluator assessing the usefulness of retrieved documents for a RAG system.

    **--- CRITICAL INSTRUCTION: Understand the Goal ---**
    The "Retrieved Context" is **NOT** the final answer. It is the raw information a separate AI will use to generate an answer. Your task is to judge if the context **CONTAINS** the necessary information for that AI to *create* a good answer. The context can contain extra, irrelevant details; this is acceptable as long as the core, useful information is present.

    **Scoring Guide (continuous scale from 0.0 to 1.0):**
    - 0.0: The context is completely irrelevant to the question.
    - 0.25: The context has minor relevance but is missing key information.
    - 0.5: The context is partially relevant but contains a lot of noise or irrelevant details.
    - 0.75: The context is highly relevant and contains the necessary information to answer the question.
    - 1.0: The context is perfectly relevant, and contains everything needed to give a complete answer.

    **User Question:**
    {question}

    **Retrieved Context:**
    {context}

    Provide your final evaluation as a JSON object with a single key: "score".

    JSON Response:
    """
)

# --- Groundedness and Completeness (Faithfulness) ---
faithfulness_score_prompt = ChatPromptTemplate.from_template(
    """You are an expert evaluator. Your task is to assess the quality of a generated answer based on a provided context.
    You must evaluate TWO aspects in a single score:
    1.  **Groundedness**: Is the answer factually supported by the context? Penalize any claims in the answer that are not found in the context.
    2.  **Completeness**: Does the answer omit any critical information from the context, especially warnings, side effects, or contraindications?

    **Scoring Guide (continuous scale from 0.0 to 1.0):**
    - 1.0: The answer is both fully supported by the context (no hallucinations) AND includes all critical details.
    - 0.75: The answer is fully supported but has a minor omission, OR it is mostly supported with no critical omissions.
    - 0.5: The answer has some unsupported claims OR omits important information (e.g., a common side effect).
    - 0.25: The answer has significant unsupported claims OR omits critical safety information (e.g., a severe warning).
    - 0.0: The answer is a complete hallucination or is dangerously misleading due to severe omissions.

    **Provided Context:**
    {context}

    **Generated Answer:**
    {answer}

    Provide your final evaluation as a JSON object with a single key: "score".

    JSON Response:
    """
)

eval_answer_relevance_chain = answer_relevance_prompt | judge_llm | RunnableLambda(parse_think_and_json)
eval_context_relevance_chain = context_relevance_prompt | judge_llm | RunnableLambda(parse_think_and_json)
eval_faithfulness_score_chain = faithfulness_score_prompt | judge_llm | RunnableLambda(parse_think_and_json)

# %%
llm = OllamaLLM(model="qwen3:8b", num_ctx=10000, reasoning=None)

with open('./evaluated_questions.txt', 'r', encoding='utf-8') as f:
  eval_questions = [line.strip() for line in f.readlines()]
evaluation_results = []

print("Starting evaluation...")

for i, question in enumerate(eval_questions):
    print(f"  Evaluating question {i+1}/{len(eval_questions)}: \"{question}\"")
    # 1. Get the response from RAG chain
    inputs = {"question": question, "llm": llm}
    rag_response = rag_app.invoke(inputs)
    documents = rag_response.get('documents', [])
    raw_output = rag_response.get('generation', "Không thể tạo câu trả lời.")
    # Parses the raw output from the generator LLM to separate the <think> tags from the final answer.
    think_match = re.search(r'<think>(.*?)</think>', raw_output, re.DOTALL)
    if think_match:
        reasoning = think_match.group(1).strip()
        # The final answer is everything *after* the closing </think> tag
        answer = raw_output[think_match.end():].strip()
    else:
        # If no think tag is found, the whole output is the answer
        reasoning = "No <think> tag found in generator output."
        answer = raw_output.strip()

    # 2. Run the evaluation chains
    ar_result = eval_answer_relevance_chain.invoke({"question": question, "answer": answer})
    cr_result = eval_context_relevance_chain.invoke({"question": question, "context": documents})
    f_result = eval_faithfulness_score_chain.invoke({"question": question, "context": documents, "answer": answer})

    # 3. Store the results
    evaluation_results.append({
        "question": question,
        "answer": answer,
        "documents": documents,
        "llm_reasoning": reasoning,
        "answer_relevance_score": ar_result.get('score'),
        "answer_relevance_reasoning": ar_result.get('reasoning'),
        "context_relevance_score": cr_result.get('score'),
        "context_relevance_reasoning": cr_result.get('reasoning'),
        "faithfulness_score": f_result.get('score'),
        "faithfulness_reasoning": f_result.get('reasoning')
    })

print("Evaluation complete!")
# Out:
# Starting evaluation...
#   Evaluating question 1/60: "Vị thuốc nào trong tài liệu có tác dụng bổ huyết?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'KÊ HUYẾT ĐẰNG...' -> Grade: YES
#   - Doc: 'Lộc Giác Giao...' -> Grade: YES
#   - Doc: 'VÔ TÂM THẢO...' -> Grade: YES
#   - Doc: 'TANG HOA...' -> Grade: YES
#   - Doc: 'Thủy lật căn, Thủy lật tử, Xuyên cốt, Cố...' -> Grade: YES
#   - Doc: 'Thịt con hạt đán...' -> Grade: YES
#   - Doc: 'LỘC THẬN...' -> Grade: NO
#   - Doc: 'Hà-xuân...' -> Grade: YES
#   - Doc: 'Khô cận, Mã-cận, So-qui, Thủy-anh...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Cốt-nột, A-từ-bột-tha, Nột-thú, On-nột-t...' -> Grade: NO
#   - Doc: 'TRƯ HUYẾT...' -> Grade: YES
#   - Doc: 'Cam-kỷ-tử, Kỷ-tử, Táo-kỷ-vương, Thiên-ti...' -> Grade: YES
#   - Doc: 'Khoáng mạch...' -> Grade: NO
#   - Doc: 'Địa hoàng, Can địa hoàng, Sinh địa, Địa ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'VỌNG NGUYỆT THANH, Hoàn tỉnh thảo, Ngọc ...' -> Grade: YES
#   - Doc: 'nhị vàng trong hoa sen, liên tu, Bạch li...' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Thược dược, Tương ly, Mộc-thược-dược, Xí...' -> Grade: YES
#   - Doc: 'Hoạt-qui-tử, A-úc-tử, Kỳ-thái-tử, Lộ-qui...' -> Grade: NO
#   - Doc: 'Gà mái trắng...' -> Grade: YES
#   - Doc: 'Lộc Giác Giao Nhập Chúc...' -> Grade: YES
#   - Doc: 'LỘC CỐT...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'TRƯ HUYẾT...' -> Score: 0.9729
#   - Doc: '...' -> Score: 0.9698
#   - Doc: 'Thược dược, Tương ly, Mộc-thược-dược, Xí...' -> Score: 0.9504
#   - Doc: 'KÊ HUYẾT ĐẰNG...' -> Score: 0.9437
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9239
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 2/60: "Vị thuốc có tác dụng an thần?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'XA CỪ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Đàn-hoàn...' -> Grade: YES
#   - Doc: 'Rau ngủ...' -> Grade: YES
#   - Doc: 'Vân Phục thần, Thiên sinh phục thần, Phụ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'TÍCH LỊCH CHÂM...' -> Grade: YES
#   - Doc: 'NGÂN BẠC, Bạch y, Chu đề, Kim phi, Long ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Thuy liên hoa, Liên thái, Minh thái...' -> Grade: YES
#   - Doc: 'XẠ TẾ...' -> Grade: YES
#   - Doc: 'Phụ chung, Con giọt sành...' -> Grade: YES
#   - Doc: 'Huyết-phách, Mao-phách, Quang-phách, Tây...' -> Grade: YES
#   - Doc: 'Dan-sa, Thần sa, Khe-sa, Tuyên sa, Chân-...' -> Grade: YES
#   - Doc: 'HOÀNG-CHI, Kim-chi...' -> Grade: YES
#   - Doc: 'quả nhãn, Tế lệ ích chí, Mặt tỳ, Yến noã...' -> Grade: YES
#   - Doc: 'Vỏ cây Hợp Hoan...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'TOAN TÁO NHÂN, Sao tảo nhân, Sình táo nh...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'SƠN CỬU...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'TÔ HỢP DU...' -> Grade: YES
#   - Doc: 'Duyên-Đơn, Duyên-Hoa, Kim-Liều, Xích-Đơn...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'VIỄN CHÍ, Nga quản chí thông, Chỉ nhục, ...' -> Grade: YES
#   - Doc: 'Vỏ sò tai tượng, Hải phiến...' -> Grade: YES
#   - Doc: 'Chuyết bối la hương, Tịch tà, An tất hươ...' -> Grade: YES
#   - Doc: 'TỬ THẠCH ANH...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'NGÂN BẠC, Bạch y, Chu đề, Kim phi, Long ...' -> Score: 0.9897
#   - Doc: 'Huyết-phách, Mao-phách, Quang-phách, Tây...' -> Score: 0.9824
#   - Doc: 'XA CỪ...' -> Score: 0.9779
#   - Doc: '...' -> Score: 0.9759
#   - Doc: 'HOÀNG-CHI, Kim-chi...' -> Score: 0.9755
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 3/60: "Những vị thuốc nào có độc tính cao, cần phải cẩn trọng khi sử dụng?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Độc hà thảo, Tu thiên hoa, Hạn hà điệp, ...' -> Grade: YES
#   - Doc: 'Mồ hôi người, NHÂN HÃN...' -> Grade: YES
#   - Doc: 'HAN...' -> Grade: YES
#   - Doc: 'HÀ-ĐỒN, Qui-ngư, Khuê-ngư, Sân-ngư, Hầu-...' -> Grade: YES
#   - Doc: 'HOÀNG-ĐÀN, Võ Doãn...' -> Grade: YES
#   - Doc: 'Con chấy...' -> Grade: YES
#   - Doc: 'Khổng tước, Việt điều, Nam khách, Ma điề...' -> Grade: YES
#   - Doc: 'KHỔNG TƯỚC, Việt điều, Nam khách, Ma điề...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'XÀ THẠCH...' -> Grade: YES
#   - Doc: 'Cao cây Ké...' -> Grade: NO
#   - Doc: 'Lang trảm, Hoàng dường tử, Hành đường từ...' -> Grade: YES
#   - Doc: 'Yên-thảo, Yên-thảo, Đạm ba có, Phản hồn ...' -> Grade: YES
#   - Doc: 'Mao-đào, Thu-nguyệt-sương-đào, Ty-đào, Đ...' -> Grade: NO
#   - Doc: 'YẾT SAO...' -> Grade: YES
#   - Doc: 'XA GIÁC...' -> Grade: YES
#   - Doc: 'Duyên tinh, Xá nữ, Sinh hồng, Tử minh, L...' -> Grade: YES
#   - Doc: 'Cây lỗi...' -> Grade: YES
#   - Doc: 'Lê, Yên chi thái, Hạc đỉnh thảo, Hồng tâ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Cứt rắn độc...' -> Grade: YES
#   - Doc: 'THẠCH LONG TỬ CAN...' -> Grade: YES
#   - Doc: 'UNG THÁI...' -> Grade: NO
#   - Doc: 'Khổ luyện tử, Kim-linh-tử, Xuyên-luyện-t...' -> Grade: YES
#   - Doc: 'Mõ sa, Khi sa, Thần sa, Kim tặc, Vô tình...' -> Grade: YES
#   - Doc: 'Long châu tử...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'KHOA ĐẦU, Khoa đầu...' -> Grade: NO
#   - Doc: 'Đào-dặc...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'HÀ-ĐỒN, Qui-ngư, Khuê-ngư, Sân-ngư, Hầu-...' -> Score: 0.9959
#   - Doc: 'Duyên tinh, Xá nữ, Sinh hồng, Tử minh, L...' -> Score: 0.9926
#   - Doc: 'HOÀNG-ĐÀN, Võ Doãn...' -> Score: 0.9901
#   - Doc: 'Độc hà thảo, Tu thiên hoa, Hạn hà điệp, ...' -> Score: 0.9323
#   - Doc: 'Mồ hôi người, NHÂN HÃN...' -> Score: 0.8684
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 4/60: "Những vị thuốc nào có tác dụng "Khu phong trừ thấp", chuyên trị các chứng đau nhức xương khớp, tê bại?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Khai kim tỏa...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Xương Hùm, Hồ-lặc-cốt, Đại-trùng-cốt, Ô-...' -> Grade: YES
#   - Doc: 'THẠCH NAM ĐẰNG...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Độc-hoạt, Độc-giao-thảo, Trường-sinh-thả...' -> Grade: YES
#   - Doc: 'HÙNG-CỐT...' -> Grade: YES
#   - Doc: 'Rượu xương Hổ...' -> Grade: YES
#   - Doc: 'TUYỀN PHÚ CĂN...' -> Grade: YES
#   - Doc: 'Phương hưởng, Trạch phần, Phù ly, Đỗ như...' -> Grade: YES
#   - Doc: 'Tam giác phong...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'TANG KÝ SINH, Tang thượng ký sinh, Kỷ ti...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Ngũ gia, Sài tất, Sài tiết, Ngũ nhai, Vă...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Chim mòng, NHẠN ĐIỂU...' -> Grade: YES
#   - Doc: 'TRƯỜNG TÙNG CĂN...' -> Grade: YES
#   - Doc: 'gừng gió...' -> Grade: YES
#   - Doc: 'TÙNG TIẾT...' -> Grade: YES
#   - Doc: 'SƠN QUI GIÁP...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'đạm ngô du, khai khẩu ngô du, nhan, ngô ...' -> Grade: YES
#   - Doc: 'cây Ráy Thiên thục...' -> Grade: YES
#   - Doc: 'cây cứt lợn, Trư-cao-mẫu, Hỏa-hiêm-thảo,...' -> Grade: YES
#   - Doc: 'Mộc qua, Ma tra, Thiết Cước lệ, Tuyên mộ...' -> Grade: YES
#   - Doc: 'UY LINH TIÊN...' -> Grade: YES
#   - Doc: 'Kim bàn thảo...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Xương Hùm, Hồ-lặc-cốt, Đại-trùng-cốt, Ô-...' -> Score: 0.9982
#   - Doc: 'cây cứt lợn, Trư-cao-mẫu, Hỏa-hiêm-thảo,...' -> Score: 0.9972
#   - Doc: '...' -> Score: 0.9967
#   - Doc: 'Khai kim tỏa...' -> Score: 0.9963
#   - Doc: 'UY LINH TIÊN...' -> Score: 0.9946
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 5/60: "Vị thuốc nào có tác dụng "Bổ Thận Tráng Dương"?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Tiên-linh-tỳ, Phóng trượng thảo, Thiên-l...' -> Grade: YES
#   - Doc: 'Phá-số-chỉ, Bà-cố-chỉ, Bồ-cốt-chi, Hồ-cử...' -> Grade: YES
#   - Doc: 'Cốt-nột, A-từ-bột-tha, Nột-thú, On-nột-t...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'TRƯ THẬN...' -> Grade: YES
#   - Doc: 'LỘC THẬN...' -> Grade: YES
#   - Doc: 'Ngũ-tinh-âm-hoa, Ngũ-tinh-thạch, Bach-th...' -> Grade: YES
#   - Doc: 'TRƯ THẬN CHÚC...' -> Grade: YES
#   - Doc: 'hạt chóc xôi...' -> Grade: YES
#   - Doc: 'Dương-thạch-tử, Dương noãn...' -> Grade: YES
#   - Doc: 'HƯƠNG-VU...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'TRU DI...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Lộc Thận Chúc...' -> Grade: YES
#   - Doc: 'HOÀNG-NGƯU-THẬN...' -> Grade: YES
#   - Doc: 'Cao-dương-nhục, Yết nhục, Miên-dương-nhụ...' -> Grade: YES
#   - Doc: 'Hoạt-qui-tử, A-úc-tử, Kỳ-thái-tử, Lộ-qui...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Tật lê, Bạch tật lê, Đồng sa uyển...' -> Grade: YES
#   - Doc: 'XÀ SÀNG TỬ, Xà túc, Xà mễ, Hủy xàng, Hu,...' -> Grade: YES
#   - Doc: 'Phạn đậu, Đậu tường, Thái đậu, Bạch-mi-đ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Cửu-thái tử...' -> Grade: YES
#   - Doc: 'Kim anh tử, Thích-lê-tử, Sơn-thạch-lựu, ...' -> Grade: YES
#   - Doc: 'Kim anh tử, Thích-lê-tử, Sơn-thạch-lựu, ...' -> Grade: YES
#   - Doc: 'NGẢI THẬT...' -> Grade: YES
#   - Doc: 'Bất điêu-thảo, Tam-mạn-thảo, Ba kích nhụ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'NGẢI THẬT...' -> Score: 0.9978
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9976
#   - Doc: 'Cốt-nột, A-từ-bột-tha, Nột-thú, On-nột-t...' -> Score: 0.9974
#   - Doc: 'Tiên-linh-tỳ, Phóng trượng thảo, Thiên-l...' -> Score: 0.9966
#   - Doc: 'LỘC THẬN...' -> Score: 0.9953
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 6/60: "ĐỖ-TRỌNG có tác dụng chính là gì và kỵ với những vị thuốc nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'ĐỖ-TRỌNG, Đỗ-trọng, Tư-trọng, Ốc-trách, ...' -> Grade: YES
#   - Doc: 'ĐỖ TRỌNG-NỘN-NHA, Miên-nha...' -> Grade: YES
#   - Doc: 'Dương-bất-thực thảo, Hoàng-đồ-quyên, Ngọ...' -> Grade: NO
#   - Doc: 'Hoàng-Đức-Tổ...' -> Grade: NO
#   - Doc: 'Hồ-trượng-thảo, Võ-trượng, Khô-trượng, C...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Toán-thông, Hồi-hồi-thông...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Đỗ-nhược-căn, Đỗ-hành, Bạch-liên, Mã-đề-...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Thủy-trúc, Áp-chích-thảo...' -> Grade: NO
#   - Doc: 'Dã-trượng-nhân, Hồ-vương-sử-giả, Nại-hà-...' -> Grade: NO
#   - Doc: 'Bò - lư, Quả-doanh, Thồ-phong, Tế-yêu-ph...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Huân-thái, Toán-đầu, Hồ, Thiên-su-ho...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Khổng tước, Việt điều, Nam khách, Ma điề...' -> Grade: NO
#   - Doc: 'Hà-xuân...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'ĐỊA-LONG-TỬ, Khâu-dẫn, Thồ-long, Hàn-dẫn...' -> Grade: NO
#   - Doc: 'HÀ-ĐỒN, Qui-ngư, Khuê-ngư, Sân-ngư, Hầu-...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lộ thảo, Mật-thảo, Quốc lão, Linh-thông,...' -> Grade: NO
#   - Doc: 'Mao-đào, Thu-nguyệt-sương-đào, Ty-đào, Đ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'ĐÔ-QUẢN-THẢO...' -> Grade: NO
#   - Doc: 'HỒNG ĐĂNG-LUNG...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'ĐỖ-TRỌNG, Đỗ-trọng, Tư-trọng, Ốc-trách, ...' -> Score: 0.9973
#   - Doc: 'ĐỖ TRỌNG-NỘN-NHA, Miên-nha...' -> Score: 0.9788
#   Passing 2 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 7/60: "HÀ THỦ Ô nổi tiếng với công dụng làm đen râu tóc. Khi bào chế vị thuốc này, cần phải kiêng kỵ dụng cụ bằng chất liệu gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Tiên-thủ-ô, Chế-thủ-ô, Dia-tinh, Cửu-châ...' -> Grade: YES
#   - Doc: 'SƠN NÔ, Hà thủ ô...' -> Grade: NO
#   - Doc: 'NGÔ ĐỒNG...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lễ tràng thảo...' -> Grade: NO
#   - Doc: 'Rượu Hoàng-tinh...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'TỪ Ô, Hiếu điều, Từ nha, Hàn nha...' -> Grade: NO
#   - Doc: 'THẠCH LỰU HOA...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Độc hà thảo, Tu thiên hoa, Hạn hà điệp, ...' -> Grade: NO
#   - Doc: 'Lê đậu, Lý đậu, Hồ đậu, Thử đậu...' -> Grade: NO
#   - Doc: 'Gầu đầu, bách xỉ sương, NHÂN ĐẦU CẤU...' -> Grade: NO
#   - Doc: 'Thủ công, Hoè-giáp, Hoè-giác, Hoè-tử...' -> Grade: NO
#   - Doc: 'Xương chim mòng, NHẠN CÓT...' -> Grade: NO
#   - Doc: 'Vuốt Hùm, móng chân Hùm...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Do-hồ, Lâu-hao, phiền, bà hao...' -> Grade: NO
#   - Doc: 'Lão nha, Hạc, Nha ô, Thất cư, Đại chủy ô...' -> Grade: NO
#   - Doc: 'Bạch-thiện-thổ, Bạch-thổ-phấn, Họa-phấn...' -> Grade: NO
#   - Doc: 'Nhau người, bào thai người, NHÂN BÀO...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Xuyên ô đầu, Xuyên-ô-đầu, Ô-đầu-tiêm, Ô ...' -> Grade: NO
#   - Doc: 'Xuyên ô, ô trác, Thảo ô, củ gấu rừng...' -> Grade: NO
#   - Doc: 'Thống Thanh Hao, Thuần Thanh Hao, Thanh ...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Hà-thiên-cao...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Tiên-thủ-ô, Chế-thủ-ô, Dia-tinh, Cửu-châ...' -> Score: 0.9993
#   Passing 1 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 8/60: "Quả óc chó có tác dụng nổi bật là gì và ai nên cẩn thận khi dùng?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Địa dương, O-long, Bạch-long, Thực-khuyề...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Trái Thị, quả Hồng chín hun khói...' -> Grade: NO
#   - Doc: 'Hương-đào, Du-hồ-đào, Hạch-đào-nhục, Bá-...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'HOÀNG-NGƯU-NÃO...' -> Grade: NO
#   - Doc: 'Ô táo, Hồng-táo, Nam táo, Hắc-táo, Can-t...' -> Grade: NO
#   - Doc: 'Cà vàng...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Khương đào, Hồ đào nhục...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'mỡ hổ nấu thành cao, Hổ Cao...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'hạt máu chó, Trúc linh...' -> Grade: NO
#   - Doc: 'Trứng cá mực...' -> Grade: NO
#   - Doc: 'Óc Chuột...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lạc-tô, Can-gia-căn, Thảo-miết-giáp, Tha...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Na Phiên, mãng cầu...' -> Grade: NO
#   - Doc: 'TƯỢNG TỨ...' -> Grade: NO
#   - Doc: 'Tang thầm, Hắc tang thầm, Nhân tỉnh, Tan...' -> Grade: NO
#   - Doc: 'Răng hổ...' -> Grade: NO
#   - Doc: 'Lộc Não...' -> Grade: NO
#   - Doc: 'Tây hồng thị, Phiên hồng thị, Dương thị ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Thạch-cự, sich-thái, oa-cự...' -> Grade: NO
#   - Doc: 'Sơn anh, Lạp anh, Anh châu, Chu đào, Hàm...' -> Grade: NO
#   - Doc: 'Lý ngư chả...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Hương-đào, Du-hồ-đào, Hạch-đào-nhục, Bá-...' -> Score: 0.9683
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.1962
#   - Doc: 'Khương đào, Hồ đào nhục...' -> Score: 0.0309
#   Passing 1 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 9/60: "Vị thuốc nào được ví như bài thuốc "Tứ vật thang" nhờ khả năng vừa phá huyết ứ, vừa sinh huyết mới, chuyên trị các bệnh về huyết ở phụ nữ?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Đan-sâm, Tu-dan-sâm, Xich-dan-sam, Huyết...' -> Grade: YES
#   - Doc: 'Đào-nhân-nê, Đào-hạch-nhân, Thoát hạch-a...' -> Grade: NO
#   - Doc: 'TAM THẤT, Sơn tất, Tam nhất mạt, Sâm tam...' -> Grade: NO
#   - Doc: 'THẠCH THÁN...' -> Grade: NO
#   - Doc: 'NGỌC TUYỀN...' -> Grade: NO
#   - Doc: 'LƯU KÝ NÔ, Ô đẳng thái, Kim ký nô, Đại d...' -> Grade: NO
#   - Doc: 'TRƯ NHỤC TỨ TÚC...' -> Grade: NO
#   - Doc: 'Hồ-trượng-thảo, Võ-trượng, Khô-trượng, C...' -> Grade: NO
#   - Doc: 'TỶ ĐẬU TỬU...' -> Grade: NO
#   - Doc: 'TÔ MỘC, Tô phương mộc, Mọc trung tôn, Da...' -> Grade: NO
#   - Doc: 'HỒNG HOA, Hồng-lam-hoa, Sinh-hoa, Tiền-b...' -> Grade: NO
#   - Doc: 'Cỏ roi ngựa, Long nha thảo, Phương cảnh ...' -> Grade: NO
#   - Doc: 'Xích đồng...' -> Grade: NO
#   - Doc: 'Củ Gấu, Sa-thảo-căn, Chế-hương-phụ, Thất...' -> Grade: NO
#   - Doc: 'Tam lăng, Kiuh Tam lăng, Fê trẻo Tam lăn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Hồ kế, Mã kế, Thích kế, Sơn ngưu bàng, K...' -> Grade: NO
#   - Doc: 'Hà-tiền, Bại-hà-diệp, Ngẫu-hà-diệp, Tiên...' -> Grade: NO
#   - Doc: 'Con Sứa, Hải triết, Hải trả, Xư bồ ngư, ...' -> Grade: NO
#   - Doc: 'TÍCH LỊCH TỬU...' -> Grade: NO
#   - Doc: 'Khương hoàng, Bảo đỉnh hương, Tử mẫu khư...' -> Grade: NO
#   - Doc: 'Ích minh, Dã thiên ma, Khổ đê thảo, Hạ k...' -> Grade: YES
#   - Doc: 'Mã lan...' -> Grade: YES
#   - Doc: 'KHƯƠNG HOÀNG, Bảo đỉnh hương, Thuật, Tử ...' -> Grade: NO
#   - Doc: 'Gà trống lông đỏ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'ĐỊA-CẨM...' -> Grade: YES
#   - Doc: 'Bạch-thiện-thổ, Bạch-thổ-phấn, Họa-phấn...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Đan-sâm, Tu-dan-sâm, Xich-dan-sam, Huyết...' -> Score: 0.9997
#   - Doc: 'Mã lan...' -> Score: 0.9917
#   - Doc: 'Ích minh, Dã thiên ma, Khổ đê thảo, Hạ k...' -> Score: 0.9436
#   - Doc: 'ĐỊA-CẨM...' -> Score: 0.9262
#   Passing 4 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 10/60: "Tác dụng chính của SINH ĐỊA HOÀNG là gì và ai không nên dùng?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'LẠC SINH HOA...' -> Grade: NO
#   - Doc: 'Địa hoàng, Can địa hoàng, Sinh địa, Địa ...' -> Grade: YES
#   - Doc: 'Đại nguyên thục địa, Lão thục địa, Chế t...' -> Grade: YES
#   - Doc: 'ĐỊA-TỦY...' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: 'TANG KÝ SINH HÀNH DIỆP...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'KHƯƠNG HOÀNG, Bảo đỉnh hương, Thuật, Tử ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'NHÂN SÂM HỒNG HOÀNG...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'SƠN CỐC CĂN...' -> Grade: NO
#   - Doc: 'Hương bồ, Cam bồ, Sanh-bồ-hoàng, Sao-bồ ...' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: 'ĐỊA-LONG-TỬ, Khâu-dẫn, Thồ-long, Hàn-dẫn...' -> Grade: NO
#   - Doc: 'Sa hoạt...' -> Grade: YES
#   - Doc: 'Nhân-thỉ, Luân-hồi-tửu, Hoàn-nguyên-than...' -> Grade: NO
#   - Doc: 'SƠN ĐẠO NIÊN KHẢ...' -> Grade: NO
#   - Doc: 'ĐỊA HUÂN...' -> Grade: YES
#   - Doc: 'Đại-giác-đậu, Trường đậu...' -> Grade: NO
#   - Doc: 'Toán-thông, Hồi-hồi-thông...' -> Grade: NO
#   - Doc: 'Tu-hoàn, Huyết-su, Thồ-chu, Thiết-chu, X...' -> Grade: NO
#   - Doc: 'TỬ THẠCH ANH...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'ĐỊA ĐẢM, Đồ-long, Nguyên-thanh, Thanh-hu...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Điềm-đình--lich, Đơn-hao, Đại-thất, Đinh...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Địa hoàng, Can địa hoàng, Sinh địa, Địa ...' -> Score: 0.9992
#   - Doc: 'Đại nguyên thục địa, Lão thục địa, Chế t...' -> Score: 0.9873
#   - Doc: '...' -> Score: 0.9801
#   - Doc: 'Hương bồ, Cam bồ, Sanh-bồ-hoàng, Sao-bồ ...' -> Score: 0.7300
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.6587
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 11/60: "Củ Mài (HOÀI-SƠN) có tác dụng nổi bật nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Thự-dự, Khánh-hoài, Sơn-dược, Thự-dược, ...' -> Grade: YES
#   - Doc: 'SƠN THỰ, củ mài, Hoài sơn...' -> Grade: YES
#   - Doc: 'NGÂN ĐIỀU ĐỨC LÝ...' -> Grade: YES
#   - Doc: 'TANG SÀI HÔI...' -> Grade: NO
#   - Doc: 'Ma dai...' -> Grade: NO
#   - Doc: 'Nguyên-tuy, Hồ-tuy-tử, Hồ-tuy-diệp, Hươn...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Huân-thái, Toán-đầu, Hồ, Thiên-su-ho...' -> Grade: NO
#   - Doc: 'HÀO-CHỦY...' -> Grade: NO
#   - Doc: 'Sa-ton, Hải-thử...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Tỏi, Huân thái, Toán đầu, Hồ, Thiên sư h...' -> Grade: NO
#   - Doc: 'Hồ ma, Vừng đen...' -> Grade: NO
#   - Doc: 'Lộc Não...' -> Grade: NO
#   - Doc: 'THẠCH-HỒ-TUY, Nga bất thực thảo, Kê tràn...' -> Grade: NO
#   - Doc: 'HÙNG-NÃO TỦY...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Cáp-lợi-xác, Cáp-lợi-phấn...' -> Grade: NO
#   - Doc: 'Việt-vương-đầu, Tich-lan-da-tr, Đế-vương...' -> Grade: NO
#   - Doc: 'Bàn tay con Rái cá...' -> Grade: NO
#   - Doc: 'HÙNG-CHÌ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Xương đầu con Hoẵng...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'HÀ-MÔ...' -> Grade: NO
#   - Doc: 'SƠN CỦNG TRÙNG...' -> Grade: NO
#   - Doc: 'Đỗ-nhược-căn, Đỗ-hành, Bạch-liên, Mã-đề-...' -> Grade: NO
#   - Doc: 'Mật con sam...' -> Grade: NO
#   - Doc: 'Rượu Hoàng-tinh...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Thự-dự, Khánh-hoài, Sơn-dược, Thự-dược, ...' -> Score: 0.9986
#   - Doc: 'NGÂN ĐIỀU ĐỨC LÝ...' -> Score: 0.8945
#   - Doc: 'SƠN THỰ, củ mài, Hoài sơn...' -> Score: 0.3034
#   Passing 3 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 12/60: "BÁCH BỘ có công dụng chính là trị ho. Ngoài ra, nó còn có tác dụng sát trùng mạnh để diệt những loại côn trùng nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Be-phy-thão, Đã thiên-môn đông, Bách nãi...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Gia cáp, Dã cấp, Bột cắp...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Hùng tước thỉ, Thanh-đan, Tước-tô...' -> Grade: NO
#   - Doc: 'Tùy kỳ bá, Bạch phụ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Ngân-hạnh, Cong-tôn-thụ, Áp-nước-tử...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Thược dược, Tương ly, Mộc-thược-dược, Xí...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Táo-đột-mặc, Táo-ngạch-mặc, Táo-yên-môi,...' -> Grade: NO
#   - Doc: 'Vương phú, Tiễn cán...' -> Grade: NO
#   - Doc: 'Hồ-giới, Bach-lat-tứ, Thục-giới...' -> Grade: NO
#   - Doc: 'Bach-duroc, Ngạnh thảo, Bạch cát cảnh, K...' -> Grade: NO
#   - Doc: 'Dã-trượng-nhân, Hồ-vương-sử-giả, Nại-hà-...' -> Grade: NO
#   - Doc: 'Tân-la-hạch-nhục, Bạch-ba-xuyến...' -> Grade: NO
#   - Doc: 'Duyên phấn, Hồ phấn, Cung phấn, Phấn tíc...' -> Grade: NO
#   - Doc: 'Bạch thảo, Bạch liễm-căn, Miêu-nhi-noãn,...' -> Grade: NO
#   - Doc: 'Hương đàn, Chiên-đàn, Chân-đàn, Dục-hươn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Thạch dương, Thủy tinh băng, Băng phấn, ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Be-phy-thão, Đã thiên-môn đông, Bách nãi...' -> Score: 0.9995
#   Passing 1 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 13/60: "Tác dụng chính của BỒ-CÔNG-ANH là gì và đặc biệt hiệu quả trong việc chữa chứng bệnh nào ở phụ nữ?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Cấu nậu thảo, Kim trâm thảo, Hoàng hoa đ...' -> Grade: YES
#   - Doc: 'Hương bồ, Cam bồ, Sanh-bồ-hoàng, Sao-bồ ...' -> Grade: NO
#   - Doc: 'Bạch-thiện-thổ, Bạch-thổ-phấn, Họa-phấn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'HOÀNG-NGƯU-ÂM-HÀNH...' -> Grade: NO
#   - Doc: 'Phóng-quang-thạch, Âm-tinh-thạch...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'TỬ THẠCH ANH...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Đạm-côn bố, Luân, Hàm-còn-bố, Luân bố...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Thảo long châu, Mã nhũ bồ-đào, Tử bồ đào...' -> Grade: NO
#   - Doc: 'NGỌC TUYỀN...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Hoa-bách-hợp, Bach-hoa bach-hop, Cường-c...' -> Grade: NO
#   - Doc: 'DƯƠNG HOAN-THẢO...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Gà trống lông đỏ...' -> Grade: NO
#   - Doc: 'Hoa cây Mộc lan...' -> Grade: NO
#   - Doc: 'HOÀNG-NGƯU-NOÃN NANG, Cồ-ngưu-noãn-nang...' -> Grade: NO
#   - Doc: 'Nga truật, Bồng nga mậu, Thanh khương, B...' -> Grade: NO
#   - Doc: 'Phá-số-chỉ, Bà-cố-chỉ, Bồ-cốt-chi, Hồ-cử...' -> Grade: NO
#   - Doc: 'Bồng sa, Bồn-sa, Lỗ-sa, Nam-man-sa, Bằng...' -> Grade: NO
#   - Doc: 'TÙNG LA CAM, Nữ la, Tùng ký sinh, Bạch u...' -> Grade: NO
#   - Doc: 'HÙNG-HOÀNG, Hùng-tinh, Thạch-hoàng, Hoàn...' -> Grade: NO
#   - Doc: 'KHOAN CÂN ĐẰNG, Nam - tục - đoạn...' -> Grade: NO
#   - Doc: 'Tu-hoàn, Huyết-su, Thồ-chu, Thiết-chu, X...' -> Grade: NO
#   - Doc: 'Củ Gấu, Sa-thảo-căn, Chế-hương-phụ, Thất...' -> Grade: NO
#   - Doc: 'Đà-ngư, Thổ-long, Trư-bà-long...' -> Grade: NO
#   - Doc: 'Tiêu hận khách, Trợ kiều hoa, Bạch hoa l...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Cấu nậu thảo, Kim trâm thảo, Hoàng hoa đ...' -> Score: 0.9991
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.4182
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.3727
#   Passing 3 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 14/60: "Vị thuốc BÁN HẠ có tác dụng chính là gì và những đối tượng nào phải hết sức cẩn trọng khi dùng?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Thủ-điền, Địa-văn, Thủy-ngọc, Dương- nhẫ...' -> Grade: YES
#   - Doc: 'TÔ BÁN HẠ...' -> Grade: YES
#   - Doc: 'KHƯƠNG BÁN HẠ, Trúc như...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Khương bán hạ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Ma du bàn hạ khúc...' -> Grade: YES
#   - Doc: 'Tiêu hận khách, Trợ kiều hoa, Bạch hoa l...' -> Grade: NO
#   - Doc: 'Hạt cây Hoàng-hoa-hao...' -> Grade: NO
#   - Doc: 'Đàn-hoàn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Ngân-hạnh, Cong-tôn-thụ, Áp-nước-tử...' -> Grade: NO
#   - Doc: 'Bạt khá, Kim tiền bạc hà, Kê tô, Nam bạc...' -> Grade: NO
#   - Doc: 'Mẫu-ma, Thanh-hao...' -> Grade: NO
#   - Doc: 'Gia-viên, Ngọc-bàn-gia, Pháo-gia, Bạch-g...' -> Grade: NO
#   - Doc: 'Do-hồ, Lâu-hao, phiền, bà hao...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Mã tiền tử, Phiên mộc biết, Khồ thật bả ...' -> Grade: NO
#   - Doc: 'NGÂN BẠC, Bạch y, Chu đề, Kim phi, Long ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Tu-hoàn, Huyết-su, Thồ-chu, Thiết-chu, X...' -> Grade: NO
#   - Doc: 'HOÀN HÒN ĐAN...' -> Grade: NO
#   - Doc: 'Bạch-hạnh-nhân, Quang-hạnh-nhân, Khổ hạn...' -> Grade: YES
#   - Doc: 'Hoài-hương, Bát-giáp-hồi-hương, Bạc-hồi-...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Kỳ-xà, Khiển-ty-xà, Long-y, Xà thế...' -> Grade: NO
#   - Doc: 'Hương bồ, Cam bồ, Sanh-bồ-hoàng, Sao-bồ ...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Thủ-điền, Địa-văn, Thủy-ngọc, Dương- nhẫ...' -> Score: 0.9997
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9906
#   - Doc: 'Khương bán hạ...' -> Score: 0.9901
#   - Doc: 'Ma du bàn hạ khúc...' -> Score: 0.9890
#   - Doc: 'KHƯƠNG BÁN HẠ, Trúc như...' -> Score: 0.9876
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 15/60: "ĐẠI HOÀNG được mệnh danh là "Tướng quân". Tại sao lại có tên gọi này và tác dụng chính của nó là gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Cầm-trang-hoàng, Vô-thanh-hồ, Tướng-quân...' -> Grade: YES
#   - Doc: 'Đại hoàng...' -> Grade: NO
#   - Doc: 'Tướng quân, Cầm văn đại hoàng, Xuyên quâ...' -> Grade: YES
#   - Doc: 'Đại hoàng...' -> Grade: YES
#   - Doc: 'Hồ-phong, Hậu-lậu-phong, Huyền-hồ-phong...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Xuyên quân...' -> Grade: YES
#   - Doc: 'Đại-hoàng, Hoang-Lương...' -> Grade: NO
#   - Doc: 'Đại hoàng thứ tốt...' -> Grade: YES
#   - Doc: 'Đại-hoàng-phong, Huyền Phong...' -> Grade: NO
#   - Doc: 'VÕ THANH HỒ...' -> Grade: YES
#   - Doc: 'HÙNG-HOÀNG, Hùng-tinh, Thạch-hoàng, Hoàn...' -> Grade: NO
#   - Doc: 'Đại kích...' -> Grade: NO
#   - Doc: 'Đại-thanh-diệp, Tùng-lam, Tiên-đại-thanh...' -> Grade: NO
#   - Doc: 'HOÀNG ĐẠI ĐẬU...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Huân-thái, Toán-đầu, Hồ, Thiên-su-ho...' -> Grade: NO
#   - Doc: 'LA HOÀNG, Cửu tầng bì quả...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Đại-đậu-quyền, Đậu-hoàng-quyền, Hoàng-qu...' -> Grade: NO
#   - Doc: 'Tu-hoàn, Huyết-su, Thồ-chu, Thiết-chu, X...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'La hoàng, Cửu tầng bì quả...' -> Grade: NO
#   - Doc: 'Hồng-nha-đại-kích, Cung-cự, Hạ-mã-tiên, ...' -> Grade: NO
#   - Doc: 'LƯU HOÀNG, Dương hậu, Lưu hoàng, Thạch l...' -> Grade: NO
#   - Doc: 'Tỏi, Huân thái, Toán đầu, Hồ, Thiên sư h...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'LỘC CÂN...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Cầm-trang-hoàng, Vô-thanh-hồ, Tướng-quân...' -> Score: 0.9988
#   - Doc: 'Tướng quân, Cầm văn đại hoàng, Xuyên quâ...' -> Score: 0.9705
#   - Doc: 'VÕ THANH HỒ...' -> Score: 0.8093
#   - Doc: 'Hồ-phong, Hậu-lậu-phong, Huyền-hồ-phong...' -> Score: 0.7619
#   - Doc: 'Xuyên quân...' -> Score: 0.5632
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 16/60: "CÁT CÁNH có tác dụng gì đối với các vị thuốc khác trong một bài thuốc và chuyên trị bệnh ở vùng nào của cơ thể?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Bach-duroc, Ngạnh thảo, Bạch cát cảnh, K...' -> Grade: YES
#   - Doc: 'Ke-tè, Lộc-đậu, Can-cát, Thiết-cát-đẳng,...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Nát-thạch, Liêu-nhủ-phản, Vũ-nát, Khô-ph...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'THẠCH THÁN...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Phương hưởng, Trạch phần, Phù ly, Đỗ như...' -> Grade: NO
#   - Doc: 'tử phong các...' -> Grade: NO
#   - Doc: 'Mộc cận bì căn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Liên cập thảo, Cam căn, Tử lan, Bạch căn...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'MIẾT ĐẦU...' -> Grade: NO
#   - Doc: 'Điếu câu, Song-câu-đẳng, Câu-câu, Điếu-đ...' -> Grade: NO
#   - Doc: 'CÁNH MẺ HÒA CÁN...' -> Grade: NO
#   - Doc: 'CẦU QUẢ CAN...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Mộc bát giác, Kim bàn thảo...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'PATIA JAPONICA DCNE et PLANC...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Cát căn...' -> Grade: NO
#   - Doc: 'Thược dược, Tương ly, Mộc-thược-dược, Xí...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Bach-duroc, Ngạnh thảo, Bạch cát cảnh, K...' -> Score: 0.9970
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9646
#   - Doc: 'Ke-tè, Lộc-đậu, Can-cát, Thiết-cát-đẳng,...' -> Score: 0.9614
#   Passing 3 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 17/60: "Vị thuốc nào  chuyên trị ho lâu ngày và tiêu chảy, kiết lỵ?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Gốc cây Kiến lan...' -> Grade: NO
#   - Doc: 'Hải-bồ-đào...' -> Grade: YES
#   - Doc: 'TÔNG LƯ HOA...' -> Grade: YES
#   - Doc: 'trái cây Lộc vừng, Kha lê lặc, Kha tử th...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Kê tô, Thủy tô, Long não bạc hà diệp, Hư...' -> Grade: NO
#   - Doc: 'Kê tô, Thủy tô, Long não bạc hà diệp, Hư...' -> Grade: NO
#   - Doc: 'Hoàng-Thạch-Chi...' -> Grade: NO
#   - Doc: 'sữa bò, ngưu nễ...' -> Grade: YES
#   - Doc: 'Nước móc sa, Lộ thủy...' -> Grade: YES
#   - Doc: 'LƯ TỪ DUYÊN...' -> Grade: NO
#   - Doc: 'Lá cây Lộc vừng...' -> Grade: YES
#   - Doc: 'Thóc để ở kho lâu năm...' -> Grade: YES
#   - Doc: 'Anh túc xác...' -> Grade: YES
#   - Doc: 'KÊ QUAN HOA TỬ...' -> Grade: YES
#   - Doc: 'Lạt già, Địa san hồ, Hải thử đằng, Cao l...' -> Grade: YES
#   - Doc: 'ĐỀ HỒ CHỦY...' -> Grade: YES
#   - Doc: 'Sa sâm, Bạch sâm, Nam sa sâm, Bắc sa sâm...' -> Grade: YES
#   - Doc: 'MIÊU THỈ...' -> Grade: NO
#   - Doc: 'hạt sen, Liên thật, Thủy chỉ, Trạch chi,...' -> Grade: YES
#   - Doc: 'KÊ ÔNG ĐẰNG...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'KÊ QUAN HOA...' -> Grade: YES
#   - Doc: 'Hồ-Đồi-Tử...' -> Grade: YES
#   - Doc: 'HÀN-THE...' -> Grade: NO
#   - Doc: 'MI VU, vi vu, Giang mi, Kỳ chỉ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'trái cây Lộc vừng, Kha lê lặc, Kha tử th...' -> Score: 0.9881
#   - Doc: 'Hải-bồ-đào...' -> Score: 0.9791
#   - Doc: 'Anh túc xác...' -> Score: 0.9587
#   - Doc: 'Sa sâm, Bạch sâm, Nam sa sâm, Bắc sa sâm...' -> Score: 0.9487
#   - Doc: 'Lá cây Lộc vừng...' -> Score: 0.9448
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 18/60: "CÔNG DỤNG chính của XUYÊN KHUNG là gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'LỘC NHUNG...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'ĐỔ-KHUNG...' -> Grade: YES
#   - Doc: 'Bạch-Khương, Xuyên-Can.Khương, Quân-Khươ...' -> Grade: NO
#   - Doc: 'NGUYÊN TINH THẠCH...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Khương-công-ngư, Châm-ngư...' -> Grade: NO
#   - Doc: 'trần nguyên hoa, dỗ nguyên, độc ngư, bại...' -> Grade: NO
#   - Doc: 'Xích cận...' -> Grade: NO
#   - Doc: 'Xuyên khung, Khung cùng, Vô cực đao khun...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'SƠN KHƯƠNG...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'TỔN NGƯ...' -> Grade: NO
#   - Doc: 'VÔ CỰC KHUNG...' -> Grade: YES
#   - Doc: 'NGUYÊN TUY...' -> Grade: NO
#   - Doc: 'SƠN NGHĨ KHOA DUYÊN CHI...' -> Grade: NO
#   - Doc: 'KHƯƠNG HOÀNG, Bảo đỉnh hương, Thuật, Tử ...' -> Grade: NO
#   - Doc: 'Khương lang, Cát khương, Thôi hoàn, Hắc ...' -> Grade: NO
#   - Doc: 'Xương ngư, Xương ngư, Xương thử, Cầu khạ...' -> Grade: NO
#   - Doc: 'Khổ luyện tử, Kim-linh-tử, Xuyên-luyện-t...' -> Grade: NO
#   - Doc: 'HÙNG-CHƯỞNG...' -> Grade: NO
#   - Doc: 'YẾN XI...' -> Grade: NO
#   - Doc: 'TỬ-TRƯỜNG-KHANH...' -> Grade: NO
#   - Doc: 'KHƯƠNG LỘ, Khương lộ...' -> Grade: NO
#   - Doc: 'Khoáng mạch...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Xuyên cận bì...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Xuyên khung, Khung cùng, Vô cực đao khun...' -> Score: 0.9525
#   - Doc: 'ĐỔ-KHUNG...' -> Score: 0.8006
#   - Doc: 'VÔ CỰC KHUNG...' -> Score: 0.0578
#   Passing 2 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 19/60: "LONG ĐẢM THẢO có những tác dụng gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Long thường thảo...' -> Grade: NO
#   - Doc: 'Lăng du, Tà chi đại sĩ, Chi long đảm, Kh...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Rãi rồng, Mạt hương kình, Long tiết, Kìn...' -> Grade: NO
#   - Doc: 'Long đảm...' -> Grade: YES
#   - Doc: 'Ỷ ĐÃI THẢO...' -> Grade: NO
#   - Doc: 'Lễ tràng thảo...' -> Grade: YES
#   - Doc: 'Long tu đằng...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Long tu thảo...' -> Grade: NO
#   - Doc: 'TOAN MAI THẢO...' -> Grade: NO
#   - Doc: 'Hải-thái, Lạc-thủ, Đạm-hải-tảo, Hải-phát...' -> Grade: NO
#   - Doc: 'LA HOÀNG, Cửu tầng bì quả...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Long-tiền-thảo, Hộ-hoa, Biện-khánh-thảo...' -> Grade: YES
#   - Doc: 'Na gia cốt, Thanh hoa long cốt, Đoàn lon...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'BAN LONG CAO...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Cam cao, Lăng cao, Bạch trạch, Chủ điền,...' -> Grade: YES
#   - Doc: 'LƯƠNG THƯỢNG TRẦN, Ô long vĩ...' -> Grade: NO
#   - Doc: 'Lăng, Quả ấu...' -> Grade: NO
#   - Doc: 'Long tu thái...' -> Grade: NO
#   - Doc: 'Lộ thảo, Mật-thảo, Quốc lão, Linh-thông,...' -> Grade: YES
#   - Doc: 'Tang thầm, Hắc tang thầm, Nhân tỉnh, Tan...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'SAM MỄ, Long trảo túc, Ap trảo bì, Long ...' -> Grade: NO
#   - Doc: 'Lô sơn sinh, Lô nhẫn thạch, Chế cam thạc...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Lăng du, Tà chi đại sĩ, Chi long đảm, Kh...' -> Score: 0.9972
#   - Doc: '...' -> Score: 0.8030
#   - Doc: 'Long đảm...' -> Score: 0.4557
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.4201
#   - Doc: 'Long-tiền-thảo, Hộ-hoa, Biện-khánh-thảo...' -> Score: 0.4175
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 20/60: "Vị thuốc nào có tác dụng chữa tê liệt nhưng lại có "đại độc"?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Phiên mộc biết, Khồ thật bả đậu, Hỏa thấ...' -> Grade: YES
#   - Doc: 'Mộc bát giác, Kim bàn thảo...' -> Grade: YES
#   - Doc: 'XA GIÁC...' -> Grade: NO
#   - Doc: 'Kim bàn thảo...' -> Grade: YES
#   - Doc: 'PATIA JAPONICA DCNE et PLANC...' -> Grade: YES
#   - Doc: 'Hạt gai dầu, Mẫu ma...' -> Grade: YES
#   - Doc: 'Ba thúc, Cương tử, Lão dương tử, Ba nhân...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lộc ma, Qui trạch ma, Thiên ma thảo, Như...' -> Grade: YES
#   - Doc: 'Mã tiền tử, Phiên mộc biết, Khồ thật bả ...' -> Grade: NO
#   - Doc: 'Mã tiền băng...' -> Grade: YES
#   - Doc: 'Khổng tước, Việt điều, Nam khách, Ma điề...' -> Grade: NO
#   - Doc: 'Rượu ngâm rắn độc...' -> Grade: YES
#   - Doc: 'Mã tràng...' -> Grade: YES
#   - Doc: 'Kỳ xà...' -> Grade: YES
#   - Doc: 'KHỔNG TƯỚC, Việt điều, Nam khách, Ma điề...' -> Grade: NO
#   - Doc: 'NHẤT LIÊN ĐIỀU...' -> Grade: NO
#   - Doc: 'Ruột ngựa, Mã tràng...' -> Grade: YES
#   - Doc: 'bồ làm đằng, Độc hành căn, Thồ Thanh mộc...' -> Grade: NO
#   - Doc: 'Đào-dặc...' -> Grade: NO
#   - Doc: 'Khoạt du, Oa chung, Lăng lễ, Phụ oa, Thổ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Độc rao, Cao phi...' -> Grade: NO
#   - Doc: 'Phản tệ xà, Địa biễn xà, Phản tị, Phúc x...' -> Grade: YES
#   - Doc: 'Hắc kim, kim, Thồ đình thiết...' -> Grade: YES
#   - Doc: 'Cây lỗi...' -> Grade: NO
#   - Doc: 'Mã niệu...' -> Grade: NO
#   - Doc: 'KÊ SẮC THẢO...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Phiên mộc biết, Khồ thật bả đậu, Hỏa thấ...' -> Score: 0.9944
#   - Doc: 'Hạt gai dầu, Mẫu ma...' -> Score: 0.9790
#   - Doc: 'Lộc ma, Qui trạch ma, Thiên ma thảo, Như...' -> Score: 0.9766
#   - Doc: 'Mộc bát giác, Kim bàn thảo...' -> Score: 0.8665
#   - Doc: 'Phản tệ xà, Địa biễn xà, Phản tị, Phúc x...' -> Score: 0.8620
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 21/60: "Công dụng chính của NGŨ VỊ TỬ là gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'SƠN NGHĨ TỬ...' -> Grade: NO
#   - Doc: 'TỬU, Oa-tô-lô, Tửu oa, Phủ thư...' -> Grade: NO
#   - Doc: 'TỰ NGƯ...' -> Grade: NO
#   - Doc: 'TỬ MẠT LỊ...' -> Grade: NO
#   - Doc: 'TỨC NGƯ TỬ...' -> Grade: NO
#   - Doc: 'VŨ THỦY...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Việt-vương-đầu, Tich-lan-da-tr, Đế-vương...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Cửu-thái tử...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'TỬ TÔ TỬ, Sao tô tử, Chích Tử tô, Gia tô...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'LƯ NGƯ...' -> Grade: NO
#   - Doc: 'NHÂN DIỆN TỬ...' -> Grade: NO
#   - Doc: 'THẠCH THỦ NGƯ, Thạch đầu ngư, Hoàng hoa ...' -> Grade: NO
#   - Doc: 'SƯ TỬ...' -> Grade: NO
#   - Doc: 'Cam-kỷ-tử, Kỷ-tử, Táo-kỷ-vương, Thiên-ti...' -> Grade: NO
#   - Doc: 'TANG THẦM TỬU...' -> Grade: NO
#   - Doc: 'NGÔ ĐỒNG TỬ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'TỬ ĐẢNG...' -> Grade: NO
#   - Doc: 'Hồ-Thông-Tử...' -> Grade: NO
#   - Doc: 'TỬ KIM NGƯU...' -> Grade: NO
#   - Doc: 'Hồ-Đồi-Tử...' -> Grade: NO
#   - Doc: 'Kim anh tử, Thích-lê-tử, Sơn-thạch-lựu, ...' -> Grade: NO
#   - Doc: 'Kim anh tử, Thích-lê-tử, Sơn-thạch-lựu, ...' -> Grade: NO
#   - Doc: 'NGỰ HOÀNG LÝ TỬ...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
# ---NODE: GENERATE (Completed)---
#   Evaluating question 22/60: "NHÂN SÂM có những tác dụng chính nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'NHÂN SÂM VIỆT NAM...' -> Grade: YES
#   - Doc: 'Nhau người, bào thai người, NHÂN BÀO...' -> Grade: NO
#   - Doc: 'Răng người, NHÂN NHA...' -> Grade: NO
#   - Doc: 'NHÂN SÂM HOA KỲ...' -> Grade: YES
#   - Doc: 'Sữa người, Nãi trấp, Tiên nhân tửu, Sinh...' -> Grade: NO
#   - Doc: 'Đan-sâm, Tu-dan-sâm, Xich-dan-sam, Huyết...' -> Grade: NO
#   - Doc: 'NHÂN SÂM, Dã sơn sâm, Qui cái, Thồ tỉnh,...' -> Grade: NO
#   - Doc: 'Nguyên-sâm, Kinh-nguyên-sâm, Ô-nguyên-sâ...' -> Grade: NO
#   - Doc: 'Sa-ton, Hải-thử...' -> Grade: NO
#   - Doc: 'KHÔNG SA SÂM, điềm cát cánh...' -> Grade: NO
#   - Doc: 'NHÂN SÂM NHỊ HỒNG...' -> Grade: YES
#   - Doc: 'Chấy rận người ta, NHÂN SẮT...' -> Grade: NO
#   - Doc: 'NHÂN SÂM LÔ...' -> Grade: YES
#   - Doc: 'Minh-dang-sâm, Hoàng-nha-dang-sâm, Thượn...' -> Grade: YES
#   - Doc: 'NHÂN SÂM HỒNG HOÀNG...' -> Grade: YES
#   - Doc: 'nhân sâm, NHÂN THÂN...' -> Grade: NO
#   - Doc: 'Cáu ghét răng người, sỉ ngận...' -> Grade: NO
#   - Doc: 'NHÂN SÂM CAO LY...' -> Grade: YES
#   - Doc: 'Râu người ta, NHÂN TỲ TU...' -> Grade: NO
#   - Doc: 'Tinh khí của người ta, NHÂN ΤΙΝΗ...' -> Grade: NO
#   - Doc: 'NHÂN SÂM TỬ...' -> Grade: YES
#   - Doc: 'NHẤN SÂM TỬU...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: 'NHÂN SÂM TU...' -> Grade: YES
#   - Doc: 'nhân sâm, NHÂN HÀM...' -> Grade: NO
#   - Doc: 'NHÂN SÂM DƯƠNG SÂM...' -> Grade: YES
#   - Doc: 'Nước bọt người ta, Kim tương, Ngọc lễ, l...' -> Grade: NO
#   - Doc: 'Ráy tai người ta, Tắc nhĩ, Não cao, Nê h...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'NHÂN SÂM VIỆT NAM...' -> Score: 0.9974
#   - Doc: 'NHÂN SÂM HOA KỲ...' -> Score: 0.9811
#   - Doc: 'NHÂN SÂM LÔ...' -> Score: 0.9768
#   - Doc: 'NHÂN SÂM CAO LY...' -> Score: 0.9748
#   - Doc: 'NHÂN SÂM TỬ...' -> Score: 0.9725
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 23/60: "Tác dụng chính của QUẾ CHI là gì?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Lệ chi nhục, Ly chi, Khuân chi, Thiên ch...' -> Grade: YES
#   - Doc: '...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'HOÀNG-CHI, Kim-chi...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Linh chi, Nham nhung, Nham đài...' -> Grade: NO
#   - Doc: 'Kim-Chi, Hoàng-Chi...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Mỡ con giải...' -> Grade: NO
#   - Doc: '...' -> Grade: NO
#   - Doc: '...' -> Grade: YES
#   - Doc: 'MIẾT CHI...' -> Grade: NO
#   - Doc: 'Hoàng-Thạch-Chi...' -> Grade: NO
#   - Doc: 'Tùy kỳ bá, Bạch phụ...' -> Grade: NO
#   - Doc: 'VIỄN CHÍ, Nga quản chí thông, Chỉ nhục, ...' -> Grade: NO
#   - Doc: 'Mộc qua chi diệp bì căn...' -> Grade: NO
# ...
#   Evaluating question 54/60: "Vị thuốc nào có tác dụng cầm mồ hôi (chỉ hãn)?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Ma Hoàng Căn...' -> Grade: YES
#   - Doc: 'TRÚC TINH...' -> Grade: YES
#   - Doc: 'Sài hồ nam...' -> Grade: NO
#   - Doc: 'Phủ mạch, Phu mạch...' -> Grade: YES
#   - Doc: 'TOAN TÁO NHÂN, Sao tảo nhân, Sình táo nh...' -> Grade: YES
#   - Doc: 'Ma Bá...' -> Grade: YES
#   - Doc: 'TỬ TÔ, Đởi diệp tô ngạnh, Xích tô, Quế n...' -> Grade: NO
#   - Doc: 'Bạch-hạnh-nhân, Quang-hạnh-nhân, Khổ hạn...' -> Grade: NO
#   - Doc: 'Hạt cây Hoàng-hoa-hao...' -> Grade: YES
#   - Doc: 'TỬ TÔ DIỆP...' -> Grade: NO
#   - Doc: 'Bạch-Khương, Xuyên-Can.Khương, Quân-Khươ...' -> Grade: YES
#   - Doc: 'Khương bán hạ...' -> Grade: NO
#   - Doc: 'Mã đâu linh, Đô làm đẳng, Mật chích đâu ...' -> Grade: NO
#   - Doc: 'Ô mai can, Ô mai nhục, Mai thật, Huân ma...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Rễ Sài hồ phương bắc...' -> Grade: NO
#   - Doc: 'La hán quả...' -> Grade: NO
#   - Doc: 'Quảng-hoắc-hương, Tiên-hoac-hương, Thồ h...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'XẠ CAN, Ô phiến căn, Tử hoa hương, Tiên ...' -> Grade: NO
#   - Doc: 'Thủ-điền, Địa-văn, Thủy-ngọc, Dương- nhẫ...' -> Grade: NO
#   - Doc: 'LÔ HOA, Lô đầu hoa, Hàn hoa...' -> Grade: YES
#   - Doc: 'KHOẢN ĐÔNG HOA, Khoản đống, Khỏa đống, Đ...' -> Grade: NO
#   - Doc: 'Hoa tầm bọng, Đô làm đẳng, Dô đâu linh, ...' -> Grade: NO
#   - Doc: 'Cứt hổ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Mã kỳ...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'MẠCH MÔN ĐÔNG, Mạch đông, Thốn mạch đông...' -> Grade: NO
#   - Doc: 'Lạt-mê-thái, Hạn-thải...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Ma Hoàng Căn...' -> Score: 0.9930
#   - Doc: 'Phủ mạch, Phu mạch...' -> Score: 0.9922
#   - Doc: 'TRÚC TINH...' -> Score: 0.9899
#   - Doc: 'TOAN TÁO NHÂN, Sao tảo nhân, Sình táo nh...' -> Score: 0.9772
#   - Doc: 'Ma Bá...' -> Score: 0.9620
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 55/60: "Khi cần phá huyết ứ, tiêu các khối tích tụ, nên dùng những vị thuốc nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Nước đái ngựa, Mã niệu...' -> Grade: YES
#   - Doc: 'Lệ thạch...' -> Grade: YES
#   - Doc: 'TỶ ĐẬU TỬU...' -> Grade: YES
#   - Doc: 'Xích thược, Sinh xích thược, Sao xích th...' -> Grade: YES
#   - Doc: 'Mã lục...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'HỒNG HOA, Hồng-lam-hoa, Sinh-hoa, Tiền-b...' -> Grade: YES
#   - Doc: 'Tam lăng, Kiuh Tam lăng, Fê trẻo Tam lăn...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Mã lục...' -> Grade: YES
#   - Doc: 'Con sò, ngõa lũng tử, Ham tữ xác, khỏi c...' -> Grade: YES
#   - Doc: 'Hoàng thạch...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Mộc tế tân...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Sài tử...' -> Grade: YES
#   - Doc: 'đốt ngó sen, Liên ngẫu tiết...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'TÔ MỘC, Tô phương mộc, Mọc trung tôn, Da...' -> Grade: YES
#   - Doc: 'Khổ thái, Trach-bai, Lộc-thủ, Mã thảo...' -> Grade: YES
#   - Doc: 'ĐỊA-CẨM...' -> Grade: YES
#   - Doc: 'Nguru-nê-ty, Tam-châu-thảo, Thiên-tử-tô...' -> Grade: YES
#   - Doc: 'MIẾT GIÁP, Đoàn ngư, Thần thủ, Hà bá tôn...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Khương hoàng, Bảo đỉnh hương, Tử mẫu khư...' -> Grade: YES
#   - Doc: 'Thiết-sắc-thảo, Tịch-cú, Nãi-đông, Huyết...' -> Grade: YES
#   - Doc: 'Miết đầu huyết...' -> Grade: YES
#   - Doc: 'TÔNG LƯ BÌ...' -> Grade: YES
#   - Doc: 'MẠCH NHA, Mạch nghiệt, Mâu mạch nha, Kho...' -> Grade: YES
#   - Doc: 'SƠN TOÁN...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Khương hoàng, Bảo đỉnh hương, Tử mẫu khư...' -> Score: 0.9858
#   - Doc: 'Tam lăng, Kiuh Tam lăng, Fê trẻo Tam lăn...' -> Score: 0.9682
#   - Doc: 'HỒNG HOA, Hồng-lam-hoa, Sinh-hoa, Tiền-b...' -> Score: 0.9580
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9304
#   - Doc: 'Nước đái ngựa, Mã niệu...' -> Score: 0.9135
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 56/60: "Để trừ tà khí, uế khí, nên dùng vị thuốc nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'UẤT KIM HƯƠNG, Trà củ ma, Hồng lam hoa, ...' -> Grade: YES
#   - Doc: 'Mao-đào, Thu-nguyệt-sương-đào, Ty-đào, Đ...' -> Grade: YES
#   - Doc: 'La lặc, Lan hương, Hương thái...' -> Grade: YES
#   - Doc: 'HƯƠNG THẢO, Nãi-hài-thảo, Nãi-hàm-thảo...' -> Grade: YES
#   - Doc: 'Rễ cây tri thù...' -> Grade: YES
#   - Doc: 'TỬ-TRƯỜNG-KHANH...' -> Grade: YES
#   - Doc: 'TỬ ĐÀN, Đàn thiện mộc, Đàn thiện hương...' -> Grade: YES
#   - Doc: 'Khương-công-ngư, Châm-ngư...' -> Grade: YES
#   - Doc: 'TÔ HỢP, Đế hương, Tô hương, Phong chi hư...' -> Grade: YES
#   - Doc: 'MI VU, vi vu, Giang mi, Kỳ chỉ...' -> Grade: YES
#   - Doc: 'Vuốt Hùm, móng chân Hùm...' -> Grade: YES
#   - Doc: 'Thai ô dược, Nuy chướng, Nuy cước chướng...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Kê-cốt-hương, Giáng-hương-mat, Tử-đẳng-h...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Yến-diệp, Yến-diệp...' -> Grade: YES
#   - Doc: 'Do-hồ, Lâu-hao, phiền, bà hao...' -> Grade: YES
#   - Doc: 'Củ kiệu...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Độc hà thảo, Tu thiên hoa, Hạn hà điệp, ...' -> Grade: YES
#   - Doc: 'THẠCH LONG SỐ...' -> Grade: YES
#   - Doc: 'VÔ HOẠN TỬ NHÂN...' -> Grade: YES
#   - Doc: 'Hạt cây Hoàng-hoa-hao...' -> Grade: YES
#   - Doc: 'Xương bồ, Xương bồ, Nghiêu cứu, Thủy kiế...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Đào-dặc...' -> Grade: YES
#   - Doc: 'Vương tôn, Mẫu mang, Hoàng tôn, Hoàn hồn...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Xuyên ô, ô trác, Thảo ô, củ gấu rừng...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'TÔ HỢP, Đế hương, Tô hương, Phong chi hư...' -> Score: 0.9857
#   - Doc: 'TỬ ĐÀN, Đàn thiện mộc, Đàn thiện hương...' -> Score: 0.9707
#   - Doc: 'Mao-đào, Thu-nguyệt-sương-đào, Ty-đào, Đ...' -> Score: 0.9683
#   - Doc: 'Độc hà thảo, Tu thiên hoa, Hạn hà điệp, ...' -> Score: 0.9654
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9594
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 57/60: "Những vị thuốc nào có tác dụng khai khiếu, tỉnh thần (chữa hôn mê, bất tỉnh)?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'TÔ HỢP DU...' -> Grade: YES
#   - Doc: 'XA CỪ...' -> Grade: NO
#   - Doc: 'Huyết-phách, Mao-phách, Quang-phách, Tây...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Ô HỢP HƯƠNG...' -> Grade: YES
#   - Doc: 'XẠ TẾ...' -> Grade: YES
#   - Doc: 'Kim cước não, Thượng long não, Cảo hương...' -> Grade: YES
#   - Doc: 'Mai hoa băng phiến, Phiến não, Thương-lo...' -> Grade: YES
#   - Doc: 'quả nhãn, Tế lệ ích chí, Mặt tỳ, Yến noã...' -> Grade: YES
#   - Doc: 'Vân Phục thần, Thiên sinh phục thần, Phụ...' -> Grade: YES
#   - Doc: 'Quả Ké, Tuyền nhĩ, Quyền nhĩ, Dương đới ...' -> Grade: YES
#   - Doc: 'Khổ qui, Thiên già tử, Thiên bào thảo, L...' -> Grade: NO
#   - Doc: 'Duyên-Đơn, Duyên-Hoa, Kim-Liều, Xích-Đơn...' -> Grade: YES
#   - Doc: 'XẠ HƯƠNG, Đương môn tử, Nguyên xạ hương,...' -> Grade: YES
#   - Doc: 'Khổ trúc duẩn...' -> Grade: NO
#   - Doc: 'Hoa-bách-hợp, Bach-hoa bach-hop, Cường-c...' -> Grade: NO
#   - Doc: 'TOAN TÁO NHÂN, Sao tảo nhân, Sình táo nh...' -> Grade: NO
#   - Doc: 'VIỄN CHÍ, Nga quản chí thông, Chỉ nhục, ...' -> Grade: YES
#   - Doc: 'THẠCH QUYẾT MINH, Hải bạng xác, Chu tử p...' -> Grade: NO
#   - Doc: 'TÍCH LỊCH CHÂM...' -> Grade: NO
#   - Doc: 'Hoàng - tùng - Tiết...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Chiều-não, Triều-não, Long-não, Chương-n...' -> Grade: YES
#   - Doc: 'Sa giác...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'MẠCH MÔN ĐÔNG, Mạch đông, Thốn mạch đông...' -> Grade: NO
#   - Doc: 'phục linh, Bạch phục linh, Bạch vân linh...' -> Grade: YES
#   - Doc: 'TÔ HỢP, Đế hương, Tô hương, Phong chi hư...' -> Grade: YES
#   - Doc: 'Giá tô, Khương giới, Thử minh, Kinh giới...' -> Grade: NO
#   - Doc: 'Bách mạch căn, Ngưu giác hoa, Đô thảo, H...' -> Grade: NO
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Ô HỢP HƯƠNG...' -> Score: 0.9928
#   - Doc: 'Mai hoa băng phiến, Phiến não, Thương-lo...' -> Score: 0.9781
#   - Doc: 'XẠ HƯƠNG, Đương môn tử, Nguyên xạ hương,...' -> Score: 0.9707
#   - Doc: 'TÔ HỢP DU...' -> Score: 0.9460
#   - Doc: 'TÔ HỢP, Đế hương, Tô hương, Phong chi hư...' -> Score: 0.8903
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 58/60: "Vị thuốc nào có thể chữa chứng liệt dương ở nam giới?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'XÀ SÀNG TỬ, Xà túc, Xà mễ, Hủy xàng, Hu,...' -> Grade: YES
#   - Doc: 'Tiên-linh-tỳ, Phóng trượng thảo, Thiên-l...' -> Grade: YES
#   - Doc: 'Mã âm hành...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'TRU DI...' -> Grade: YES
#   - Doc: 'hạt chóc xôi...' -> Grade: YES
#   - Doc: 'Bất điêu-thảo, Tam-mạn-thảo, Ba kích nhụ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Già nam hương, Mật kết, Kỳ nam hương, Nh...' -> Grade: YES
#   - Doc: 'Phá-số-chỉ, Bà-cố-chỉ, Bồ-cốt-chi, Hồ-cử...' -> Grade: YES
#   - Doc: 'TỬ KIM ĐẲNG...' -> Grade: YES
#   - Doc: 'Cốt-nột, A-từ-bột-tha, Nột-thú, On-nột-t...' -> Grade: YES
#   - Doc: 'Mộc liên tử, Mộc man đầu, Qui man đầu...' -> Grade: YES
#   - Doc: 'SƠN DƯƠNG, Nguyên dương, Ngô dương, Dã d...' -> Grade: YES
#   - Doc: 'TRƯ NÃO...' -> Grade: YES
#   - Doc: 'Đại kích miêu...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'NGỰ CẤU KIM THỦY...' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Mộc man đầu, Qui man đầu...' -> Grade: YES
#   - Doc: 'Bách bội, Ngưu hành, Xuyên ngưu tất, Hoà...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lá cây mã đề, Mã đề...' -> Grade: YES
#   - Doc: 'Mộc cận hoa...' -> Grade: NO
#   - Doc: 'Hồ chưởng, Sinh nam tinh, Thục nam tinh,...' -> Grade: YES
#   - Doc: 'Mộc cận, Ngược tử hoa, Bạch cận hoa, Mộc...' -> Grade: NO
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'XÀ SÀNG TỬ, Xà túc, Xà mễ, Hủy xàng, Hu,...' -> Score: 0.9940
#   - Doc: 'Tiên-linh-tỳ, Phóng trượng thảo, Thiên-l...' -> Score: 0.9915
#   - Doc: '...' -> Score: 0.9909
#   - Doc: 'TRU DI...' -> Score: 0.9870
#   - Doc: 'Bất điêu-thảo, Tam-mạn-thảo, Ba kích nhụ...' -> Score: 0.9850
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 59/60: "Để chữa chứng khí hư, bạch đới ở phụ nữ, có thể dùng những vị thuốc nào?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'TOAN MÊ MÊ THẢO...' -> Grade: YES
#   - Doc: 'Mã đạo...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Hồ kế, Mã kế, Thích kế, Sơn ngưu bàng, K...' -> Grade: YES
#   - Doc: 'LẠC ĐÀ MAO...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'SƠN TỪ THẠCH...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Xuân xư căn bì, Xuân căn bạch bì, Xú hu ...' -> Grade: YES
#   - Doc: 'HOÀNG-NGƯU-ÂM-HÀNH...' -> Grade: YES
#   - Doc: 'Bạch-thiện-thổ, Bạch-thổ-phấn, Họa-phấn...' -> Grade: YES
#   - Doc: 'Gà trống lông đỏ...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: '...' -> Grade: YES
#   - Doc: 'Củ Gấu, Sa-thảo-căn, Chế-hương-phụ, Thất...' -> Grade: YES
#   - Doc: 'Hỏa-thông, Thái-chi, Hồng-khoải...' -> Grade: YES
#   - Doc: 'HỒNG HOA, Hồng-lam-hoa, Sinh-hoa, Tiền-b...' -> Grade: NO
#   - Doc: 'Mộc cận hoa...' -> Grade: NO
#   - Doc: 'Hồ-kế, Miêu-kế, Mã-kế, Thích-kế, Sơn-ngư...' -> Grade: YES
#   - Doc: 'Lý ngư cốt...' -> Grade: YES
#   - Doc: 'ĐỊA-CẨM-THẢO, Dạ-quang, Thừa-quang, Địa-...' -> Grade: YES
#   - Doc: 'ĐỊA-CẨM...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: NO
#   - Doc: 'Lộc Giác Giao...' -> Grade: YES
#   - Doc: 'KHƯƠNG HOÀNG, Bảo đỉnh hương, Thuật, Tử ...' -> Grade: YES
#   - Doc: 'Nhân-thỉ, Luân-hồi-tửu, Hoàn-nguyên-than...' -> Grade: YES
#   - Doc: 'TỬ BỐI KIM BÀN...' -> Grade: YES
#   - Doc: 'Phế sương, Bạch phế, Phế tỉnh...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Hồ kế, Mã kế, Thích kế, Sơn ngưu bàng, K...' -> Score: 0.9931
#   - Doc: 'TOAN MÊ MÊ THẢO...' -> Score: 0.9918
#   - Doc: 'SƠN TỪ THẠCH...' -> Score: 0.9887
#   - Doc: 'Mã đạo...' -> Score: 0.9864
#   - Doc: 'Không có tên khác được liệt kê....' -> Score: 0.9841
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
#   Evaluating question 60/60: "Những vị thuốc nào có tác dụng tiêu thực, chữa đầy bụng, ăn không tiêu?"
# ---NODE: RETRIEVE (Completed)---
#   Retrieved 30 document chunks.
# ---NODE: GRADE DOCUMENTS (Completed)---
#   - Doc: 'Kiến Thần khúc, Lục Thần khúc, Phạm chỉ ...' -> Grade: YES
#   - Doc: 'Mộc hương, Quảng mộc hương, Ngũ mộc hươn...' -> Grade: YES
#   - Doc: 'Mã kỳ tử...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Bột Đại Mạch...' -> Grade: YES
#   - Doc: 'Quảng mộc hương, Ngũ mộc hương, Nam mộc ...' -> Grade: YES
#   - Doc: 'Hồ Tiêu...' -> Grade: YES
#   - Doc: 'THẠCH THỦ NGƯ TƯỞNG...' -> Grade: YES
#   - Doc: 'Đậu Khấu, Ôi Thảo quả, Thảo quả nhân...' -> Grade: YES
#   - Doc: 'Cơm gạo ủ mốc vàng, Hoàng-y, Mách-hoàng,...' -> Grade: YES
#   - Doc: 'TẦN QUẢ...' -> Grade: YES
#   - Doc: 'Mã đề, O vu, Địa lật...' -> Grade: YES
#   - Doc: 'Mộc tế tân...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Lai bặc chúc...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Nãi nãi quả, Ba la, Bách nhãn lê, Ba la ...' -> Grade: YES
#   - Doc: 'Lạt-mê-thái, Hạn-thải...' -> Grade: YES
#   - Doc: 'Thai ô dược, Nuy chướng, Nuy cước chướng...' -> Grade: YES
#   - Doc: 'Lúa mạch...' -> Grade: YES
#   - Doc: 'VI THÁI...' -> Grade: NO
#   - Doc: 'quả lới, Ích chi tử, Anh hoa khố...' -> Grade: YES
#   - Doc: 'TƯỚC MẠCH, Yến mạch, Ngưu tinh thảo, Tướ...' -> Grade: YES
#   - Doc: 'Trái cam Phật thủ...' -> Grade: YES
#   - Doc: 'Thường cầu, Tra nhục, Mao tra, Sơn lý hồ...' -> Grade: YES
#   - Doc: 'hồ thỏa tử, Hồ tuy tử...' -> Grade: YES
#   - Doc: 'Không có tên khác được liệt kê....' -> Grade: YES
#   - Doc: 'Gỗ cây sam...' -> Grade: YES
#   - Doc: 'Mã giáp, Giang-diêu, Minh-ngõa, Mã-giáp,...' -> Grade: YES
#   - Doc: 'HOÀNG ĐẠI ĐẬU...' -> Grade: YES
# ---NODE: RERANK DOCUMENTS---
#   Reranking results:
#   - Doc: 'Kiến Thần khúc, Lục Thần khúc, Phạm chỉ ...' -> Score: 0.9966
#   - Doc: 'Cơm gạo ủ mốc vàng, Hoàng-y, Mách-hoàng,...' -> Score: 0.9849
#   - Doc: 'Quảng mộc hương, Ngũ mộc hương, Nam mộc ...' -> Score: 0.9835
#   - Doc: 'Mã kỳ tử...' -> Score: 0.9816
#   - Doc: 'Thai ô dược, Nuy chướng, Nuy cước chướng...' -> Score: 0.9788
#   Passing 5 documents to the generator.
# ---NODE: GENERATE (Completed)---
# Evaluation complete!

# %%
results_df = pd.DataFrame(evaluation_results)

# Calculate average scores
avg_ar_score = results_df['answer_relevance_score'].mean()
avg_cr_score = results_df['context_relevance_score'].mean()
avg_f_score = results_df['faithfulness_score'].mean()

print(f"Evaluation Summary (Scale: 0.0 to 1.0):")
print(f"  - Average Answer Relevance: {avg_ar_score:.2f}")
print(f"  - Average Context Relevance: {avg_cr_score:.2f}")
print(f"  - Average Faithfulness: {avg_f_score:.2f}")

results_df.to_csv('evaluation_records.csv', index=False, encoding='utf-8-sig')
# Out:
# Evaluation Summary (Scale: 0.0 to 1.0):
#   - Average Answer Relevance: 1.00
#   - Average Context Relevance: 0.97
#   - Average Faithfulness: 0.67
